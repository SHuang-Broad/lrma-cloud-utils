# %%
# auto reloading of local scripts under dev
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import json

# %%
import pprint
pp = pprint.PrettyPrinter(indent=1, sort_dicts=False)

# %%
# load local lib
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.cromwell_utils import *

# %%
CROMWELL_METADATA_MODEL_EXPLANATION.print()
# Out:
# Here we explain the assumptions and the model used in interpreting Cromwell Metadata Tree. We assume there exists three types of computing nodes:
#   1) simple tasks, which are computing units defined in WDL with keyword "task", and maps to concrete computing instances;
#   2) subworkflows (subWF), which are computing units defined in WDL with keyword "workflow", and does not map to concrete computing instances, but delegates to other computing nodes;
#   3) scatters, which are computing units signified in WDL with keyword "scatter", and does not map to concrete computing instances, but have homogenous shards. Each shard may compose of several computing nodes.
#
# We assume a simple task's json is representable by list of a (relatively) simple dict. The length of the list is the # of attempts made for preemptible tasks. The json contains almost all the following keys:
# ['attempt', 'backend', 'backendLabels', 'backendLogs', 'backendStatus', 'callCaching', 'callRoot', 'commandLine', 'compressedDockerSize', 'dockerImageUsed', 'end', 'executionEvents', 'executionStatus', 'failures', 'inputs', 'jes', 'jobId', 'labels', 'outputs', 'preemptible', 'returnCode', 'runtimeAttributes', 'shardIndex', 'start', 'stderr', 'stdout']
#
# We assume a subWF's json is representable by a length-1 list, where the only element is a dict holding the signatory key 'subWorkflowMetadata'. Under 'subWorkflowMetadata' is a dict with two important keys: 'workflowName' and 'calls'. 'workflowName' holds the alias of the subWF, whereas the relayed-to computing nodes are held under 'calls' as dictionaries. Each dictionary is of length-1, where the key is the name of the computing node.
#
# We assume a scatter's json is represented by a list whose length is always > 1. Here the situation can be divided into two sub-cases:
#   A simple scatter's shards are simple tasks (or their multiple attempts).
#   A complex scatter's shards are, more complicated. In this sub-case we assume each shard is represented by a list. In the list, possible values are [simple task, subWF, nested scatter] (nested scatter isn't supported yet). We refer to them as 'callables'. The length of the list for a shard, then, is the # of these callables called in that shard.

# %% [markdown]
# ## Build the tree

# %%
with open('/Users/shuang/Desktop/jonn.big.metadata.json', 'r') as ff:
    jonns_workflow = json.load(ff)

# %%
jonns_model = WorkflowMinimumDiagnosisMetadata(jonns_workflow)

# %%
len(jonns_model.tree)
# Out:
# 44

# %%
jonns_model.tree[1]

# %%
jonns_model.tree[0]
# Out:
# {'t_22_MergeS2ECcsReclaimedArrayElementSubshards': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6cb20>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6ce50>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6cd00>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6ccd0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6cac0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6ca60>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6cee0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6cf40>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6cfa0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e6ce20>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d0a0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d100>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d160>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d1c0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d220>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d2b0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d310>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d370>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d3d0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d430>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d490>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d4f0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d550>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d5b0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d610>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d670>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d6d0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d730>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d790>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d7f0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d850>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d8b0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d910>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d940>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d9d0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7da30>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7da90>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7daf0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7db50>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7dbb0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7dc10>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7dc70>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7dcd0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7dd30>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7dd90>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7ddf0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7de50>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7deb0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7df10>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7dfd0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7df40>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e7d040>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e800d0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80130>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80190>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e801f0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80250>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e802b0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80310>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80370>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e803d0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80430>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80490>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e804f0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80550>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e805b0>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80610>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107e80670>,
#   <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x107
print(f"Type of the only callable in a shard {type(u)} (dict expected), its len {len(u)} (expects 1).")
k = next(iter(u.keys()))
v = next(iter(u.values()))
print(f"the only callable in a shard is named {k} (expects t_21_SegmentS2ECcsReclaimedReads), its value is a {type(v)} (list expected), and len {len(v)} (expects 10).")
# Out:
# len x: 1 (expects 1).
# len y: 300 (expects 300).
# type of an element in y: <class 'tuple'> (tuple expected).
# And its shard index is expected to be 1: 1
# The shard is expected to hold a single callable, represented by a length-1 list: type <class 'list'>, length 1
# Type of the only callable in a shard <class 'dict'> (dict expected), its len 1 (expects 1).
# the only callable in a shard is named t_21_SegmentS2ECcsReclaimedReads (expects t_21_SegmentS2ECcsReclaimedReads), its value is a <class 'list'> (list expected), and len 10 (expects 10).

# %%
x[0]
# Out:
# {'ScatterAt296_18': [([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0160>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f01f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0250>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f02b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0310>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0370>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f03d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0430>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0490>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f04f0>]}],
#    0),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0550>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f05b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0610>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0670>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f06d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0730>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0790>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f07f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0850>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f08b0>]}],
#    1),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0910>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0970>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f09d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0a30>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0a90>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0af0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0b50>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0bb0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0c10>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0c70>]}],
#    2),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0cd0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0d30>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0d90>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0df0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0e50>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0eb0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0f10>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0f70>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f0fd0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f01c0>]}],
#    3),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f70d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7130>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7190>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f71f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7250>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f72b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7310>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7370>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f73d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7430>]}],
#    4),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7490>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f74f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7550>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f75b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7610>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7670>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f76d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7730>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7790>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f77f0>]}],
#    5),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7850>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f78b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7910>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7970>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f79d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7a30>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7a90>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7af0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7b50>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7bb0>]}],
#    6),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7c10>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7c70>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7cd0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7d30>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7d90>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7df0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7e50>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7eb0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7f10>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7f70>]}],
#    7),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7fd0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3f7040>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd0d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd130>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd190>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd1f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd250>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd2b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd310>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd370>]}],
#    8),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd3d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd430>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd490>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd4f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd550>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd5b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd610>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd670>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd6d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd730>]}],
#    9),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd790>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd7f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd850>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd8b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd910>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd970>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd9d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fda30>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fda90>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdaf0>]}],
#    10),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdb50>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdbb0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdc10>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdc70>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdcd0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdd30>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdd90>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fddf0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fde50>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdeb0>]}],
#    11),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdf10>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdf70>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fdfd0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f3fd040>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4030d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403130>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403190>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4031f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403250>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4032b0>]}],
#    12),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403310>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403370>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4033d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403430>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403490>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4034f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403550>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4035b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403610>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403670>]}],
#    13),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4036d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403730>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403790>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4037f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403850>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4038b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403910>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403970>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4039d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403a30>]}],
#    14),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403a90>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403af0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403b50>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403bb0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403c10>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403c70>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403cd0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403d30>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403d90>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403df0>]}],
#    15),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403e50>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403eb0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403f10>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403f70>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403fd0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f403040>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4090d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f409130>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f409190>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4091f0>]}],
#    16),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f409250>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4092b0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f409310>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f409370>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4093d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f409430>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f409490>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f4094f0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11
,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56f8e0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56f940>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56f9a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fa00>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fa60>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fac0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fb20>]}],
#    283),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fb80>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fbe0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fc40>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fca0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fd00>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fd60>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fdc0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fe20>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fe80>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56fee0>]}],
#    284),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56ff40>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56ffa0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f56f040>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5750a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575100>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575160>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5751c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575220>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575280>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5752e0>]}],
#    285),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575340>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5753a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575400>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575460>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5754c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575520>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575580>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5755e0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575640>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5756a0>]}],
#    286),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575700>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575760>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5757c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575820>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575880>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5758e0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575940>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5759a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575a00>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575a60>]}],
#    287),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575ac0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575b20>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575b80>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575be0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575c40>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575ca0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575d00>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575d60>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575dc0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575e20>]}],
#    288),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575e80>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575ee0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575f40>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575fa0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f575040>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c0a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c100>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c160>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c1c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c220>]}],
#    289),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c280>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c2e0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c340>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c3a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c400>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c460>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c4c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c520>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c580>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c5e0>]}],
#    290),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c640>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c6a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c700>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c760>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c7c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c820>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c880>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c8e0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c940>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c9a0>]}],
#    291),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57ca00>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57ca60>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cac0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cb20>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cb80>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cbe0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cc40>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cca0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cd00>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cd60>]}],
#    292),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cdc0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57ce20>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57ce80>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cee0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cf40>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57cfa0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f57c040>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582040>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582100>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582160>]}],
#    293),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5821c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582220>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582280>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5822e0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582340>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5823a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582400>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582460>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5824c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582520>]}],
#    294),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582580>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5825e0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582640>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5826a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582700>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582760>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5827c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582820>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582880>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5828e0>]}],
#    295),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582940>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5829a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582a00>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582a60>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582ac0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582b20>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582b80>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582be0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582c40>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582ca0>]}],
#    296),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582d00>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582d60>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582dc0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582e20>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582e80>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582ee0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582f40>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f582fa0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5820d0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5880a0>]}],
#    297),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588100>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588160>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5881c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588220>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588280>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5882e0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588340>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5883a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588400>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588460>]}],
#    298),
#   ([{'t_21_SegmentS2ECcsReclaimedReads': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5884c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588520>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588580>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5885e0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588640>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5886a0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588700>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588760>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f5887c0>,
#       <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11f588820>]}],
#    299)]}

# %% [markdown]
# ## Present the tree

# %% [markdown]
# ## Show topology in text form

# %%
jonns_model.topology()
# Out:
# Workflow:   MASseqStarcodeCbcParameterSweep
#
# Workflow: MASseqStarcodeCbcParameterSweep, 23 leaves, 19 simple scatters, 0 subworkflows, 2 complex scatters
#
#   Level-0 simple scatter: MASseqStarcodeCbcParameterSweep.t_07_RemoveKineticsTags, 300 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#   Level-0 simple scatter: MASseqStarcodeCbcParameterSweep.t_08_FindCCSReport, 300 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#   Level-0 simple scatter: MASseqStarcodeCbcParameterSweep.t_09_FilterS2EByMinReadQuality, 300 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#   Level-0 simple scatter: MASseqStarcodeCbcParameterSweep.t_10_GetS2ERCcsRejectedReads, 300 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#   Level-0 simple scatter: MASseqStarcodeCbcParameterSweep.t_11_ExtractS2ECcsReclaimableReads, 300 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-6/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-6.log
#       shard 7 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-7/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-7.log
#       shard 8 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-8/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-8.log
#       shard 9 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-9/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-9.log
#       shard 10 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-10/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-10.log
#       shard 11 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-11/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-11.log
#       shard 12 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-12/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-12.log
#       shard 13 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-13/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-13.log
#       shard 14 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-14/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-14.log
#       shard 15 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-15/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-15.log
#       shard 16 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-16/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-16.log
#       shard 17 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-17/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-17.log
#       shard 18 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-18/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-18.log
#       shard 19 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-19/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-19.log
#       shard 20 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-20/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-20.log
#       shard 21 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-21/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-21.log
#       shard 22 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-22/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-22.log
#       shard 23 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-23/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-23.log
#       shard 24 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-24/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-24.log
#       shard 25 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-25/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-25.log
#       shard 26 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-26/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-26.log
#       shard 27 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-27/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-27.log
#       shard 28 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-28/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-28.log
#       shard 29 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-29/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-29.log
#       shard 30 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-30/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-30.log
#       shard 31 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-31/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-31.log
#       shard 32 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-32/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-32.log
#       shard 33 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-33/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-33.log
#       shard 34 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-34/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-34.log
#       shard 35 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-35/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-35.log
#       shard 36 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-36/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-36.log
#       shard 37 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-37/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-37.log
#       shard 38 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-38/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-38.log
#       shard 39 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-39/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-39.log
#       shard 40 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-40/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-40.log
#       shard 41 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-41/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-41.log
#       shard 42 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-42/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-42.log
#       shard 43 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-43/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-43.log
#       shard 44 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-44/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-44.log
#       shard 45 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-45/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-45.log
#       shard 46 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-46/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-46.log
#       shard 47 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-47/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-47.log
#       shard 48 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-48/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-48.log
#       shard 49 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-49/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-49.log
#       shard 50 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-50/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-50.log
#       shard 51 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-51/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-51.log
#       shard 52 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-52/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-52.log
#       shard 53 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-53/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-53.log
#       shard 54 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-54/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-54.log
#       shard 55 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-55/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-55.log
#       shard 56 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-56/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-56.log
#       shard 57 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-57/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-57.log
#       shard 58 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-58/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-58.log
#       shard 59 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-59/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-59.log
#       shard 60 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-60/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-60.log
#       shard 61 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-61/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-61.log
#       shard 62 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-62/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-62.log
#       shard 63 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-63/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-63.log
#       shard 64 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-64/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-64.log
#       shard 65 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-65/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-65.log
#       shard 66 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-66/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-66.log
#       shard 67 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-67/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-67.log
#       shard 68 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-68/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-68.log
#       shard 69 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-69/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-69.log
#       shard 70 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-70/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-70.log
#       shard 71 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-71/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-71.log
#       shard 72 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-72/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-72.log
#       shard 73 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-73/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-73.log
#       shard 74 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-74/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-74.log
#       shard 75 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-75/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-75.log
#       shard 76 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-76/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-76.log
#       shard 77 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-77/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-77.log
#       shard 78 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-78/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-78.log
#       shard 79 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-79/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-79.log
#       shard 80 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-80/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-80.log
#       shard 81 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-81/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-81.log
#       shard 82 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-82/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-82.log
#       shard 83 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-83/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-83.log
#       shard 84 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-84/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-84.log
#       shard 85 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-85/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-85.log
#       shard 86 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-86/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-86.log
#       shard 87 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-87/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-87.log
#       shard 88 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-88/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-88.log
#       shard 89 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-89/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-89.log
#       shard 90 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-90/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-90.log
#       shard 91 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-91/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-91.log
#       shard 92 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-92/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-92.log
#       shard 93 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-93/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-93.log
#       shard 94 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-94/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-94.log
#       shard 95 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-95/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-95.log
#       shard 96 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-96/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-96.log
#       shard 97 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-97/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-97.log
#       shard 98 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-98/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-98.log
#       shard 99 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-99/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-99.log
#       shard 100 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-100/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-100.log
#       shard 101 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-101/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-101.log
#       shard 102 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-102/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-102.log
#       shard 103 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-103/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-103.log
#       shard 104 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-104/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-104.log
#       shard 105 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-105/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-105.log
#       shard 106 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-106/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-106.log
#       shard 107 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-107/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-107.log
#       shard 108 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-108/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-108.log
#       shard 109 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-109/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-109.log
#       shard 110 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-110/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-110.log
#       shard 111 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-111/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-111.log
#       shard 112 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-112/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-112.log
#       shard 113 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-113/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-113.log
#       shard 114 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-114/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-114.log
#       shard 115 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-115/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-115.log
#       shard 116 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-116/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-116.log
#       shard 117 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-117/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-117.log
#       shard 118 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-118/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-118.log
#       shard 119 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-119/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-119.log
#       shard 120 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-120/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-120.log
#       shard 121 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-121/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-121.log
#       shard 122 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-122/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-122.log
#       shard 123 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-123/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-123.log
#       shard 124 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-124/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-124.log
#       shard 125 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-125/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-125.log
#       shard 126 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-126/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-126.log
#       shard 127 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-127/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-127.log
#       shard 128 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-128/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-128.log
#       shard 129 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-129/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-129.log
#       shard 130 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-130/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-130.log
#       shard 131 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-131/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-131.log
#       shard 132 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-132/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-132.log
#       shard 133 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-133/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-133.log
#       shard 134 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-134/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-134.log
#       shard 135 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-135/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-135.log
#       shard 136 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-136/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-136.log
#       shard 137 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-137/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-137.log
#       shard 138 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-138/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-138.log
#       shard 139 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-139/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-139.log
#       shard 140 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-140/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-140.log
# ...
#       shard 253 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-253/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-253.log
#       shard 254 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-254/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-254.log
#       shard 255 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-255/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-255.log
#       shard 256 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-256/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-256.log
#       shard 257 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-257/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-257.log
#       shard 258 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-258/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-258.log
#       shard 259 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-259/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-259.log
#       shard 260 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-260/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-260.log
#       shard 261 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-261/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-261.log
#       shard 262 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-262/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-262.log
#       shard 263 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-263/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-263.log
#       shard 264 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-264/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-264.log
#       shard 265 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-265/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-265.log
#       shard 266 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-266/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-266.log
#       shard 267 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-267/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-267.log
#       shard 268 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-268/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-268.log
#       shard 269 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-269/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-269.log
#       shard 270 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-270/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-270.log
#       shard 271 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-271/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-271.log
#       shard 272 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-272/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-272.log
#       shard 273 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-273/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-273.log
#       shard 274 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-274/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-274.log
#       shard 275 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-275/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-275.log
#       shard 276 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-276/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-276.log
#       shard 277 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-277/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-277.log
#       shard 278 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-278/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-278.log
#       shard 279 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-279/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-279.log
#       shard 280 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-280/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-280.log
#       shard 281 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-281/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-281.log
#       shard 282 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-282/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-282.log
#       shard 283 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-283/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-283.log
#       shard 284 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-284/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-284.log
#       shard 285 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-285/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-285.log
#       shard 286 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-286/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-286.log
#       shard 287 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-287/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-287.log
#       shard 288 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-288/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-288.log
#       shard 289 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-289/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-289.log
#       shard 290 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-290/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-290.log
#       shard 291 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-291/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-291.log
#       shard 292 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-292/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-292.log
#       shard 293 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-293/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-293.log
#       shard 294 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-294/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts-294.log
#       shard 295 was attempted 2 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/MASseqStarcodeCbcParameterSweep/b33df17f-59de-4141-8175-d58e7851892d/call-t_33_CorrectBarcodesWithStarcodeSeedCounts/shard-295/attempt-2/t_33_CorrectBarcodesWithStarcodeSeedCounts
,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29cd0>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29d30>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29d90>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29df0>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29e50>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29eb0>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29f10>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29f70>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29fd0>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd299a0>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e0d0>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e130>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e190>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e1f0>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e250>,
#      <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e2b0>]}]},
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd29040>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e040>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e3a0>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e400>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e460>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e4c0>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e520>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e580>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e5e0>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd2e640>]

# %%
my_model.topology()
# Out:
# Workflow:   PBCCSWholeGenome
#
# Workflow: PBCCSWholeGenome, 10 leaves, 0 simple scatters, 1 subworkflows, 0 complex scatters
#
#   Level-0 subworkflow: PBCCSWholeGenome.CallVariants, 3 leaves, 4 simple scatters, 1 subworkflows, 0 complex scatters
#
#     Level-1 simple scatter: PBCCSWholeGenome.CallVariants.Call, 25 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#     Level-1 simple scatter: PBCCSWholeGenome.CallVariants.Discover, 25 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#     Level-1 simple scatter: PBCCSWholeGenome.CallVariants.Sniffles, 25 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#     Level-1 simple scatter: PBCCSWholeGenome.CallVariants.SubsetBam, 25 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#     Level-1 subworkflow: PBCCSWholeGenome.CallVariants.DVP, 2 leaves, 3 simple scatters, 0 subworkflows, 0 complex scatters
#
#       Level-2 simple scatter: PBCCSWholeGenome.CallVariants.DVP.DV, 21 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#       Level-2 simple scatter: PBCCSWholeGenome.CallVariants.DVP.PEPPER, 53 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#       Level-2 simple scatter: PBCCSWholeGenome.CallVariants.DVP.SubsetBam, 21 shard-attempts, 0 simple scatters, 0 subworkflows, 0 complex scatters

# %%
my_model.diagnose(show_success_too=True)
# Out:
# Workflow:   PBCCSWholeGenome
#             (uuid: 18378026-20e0-40a2-a824-341e7db9017c)
# Status:     Succeeded
# Wall-Clock: 6:44
#
#
# Diagnosis
#
#   PBCCSWholeGenome.FinalizeAlignedBai is not sharded, was attempted 1 times, ultimately succeeded.
#   PBCCSWholeGenome.FinalizeAlignedBam is not sharded, was attempted 1 times, ultimately succeeded.
#   PBCCSWholeGenome.FinalizeAlignedPbi is not sharded, was attempted 1 times, ultimately succeeded.
#   PBCCSWholeGenome.FinalizeDVPEPPERGVcf is not sharded, was attempted 1 times, ultimately succeeded.
#   PBCCSWholeGenome.FinalizeDVPEPPERTbi is not sharded, was attempted 1 times, ultimately succeeded.
#   PBCCSWholeGenome.FinalizeDVPEPPERVcf is not sharded, was attempted 1 times, ultimately succeeded.
#   PBCCSWholeGenome.FinalizePBSV is not sharded, was attempted 1 times, ultimately succeeded.
#   PBCCSWholeGenome.FinalizeSniffles is not sharded, was attempted 1 times, ultimately succeeded.
#   PBCCSWholeGenome.IndexCCSUnalignedReads is not sharded, was attempted 1 times, ultimately succeeded.
#   PBCCSWholeGenome.MergeAllReads is not sharded, was attempted 1 times, ultimately succeeded.
#     PBCCSWholeGenome.CallVariants.MakeChrIntervalList is not sharded, was attempted 1 times, ultimately succeeded.
#     PBCCSWholeGenome.CallVariants.MergePBSVVCFs is not sharded, was attempted 1 times, ultimately succeeded.
#     PBCCSWholeGenome.CallVariants.MergeSnifflesVCFs is not sharded, was attempted 1 times, ultimately succeeded.
#       PBCCSWholeGenome.CallVariants.Call.Call has 25 shards,
#         shard 0 was attempted 1 times, ultimately succeeded.
#         shard 1 was attempted 1 times, ultimately succeeded.
#         shard 2 was attempted 1 times, ultimately succeeded.
#         shard 3 was attempted 1 times, ultimately succeeded.
#         shard 4 was attempted 1 times, ultimately succeeded.
#         shard 5 was attempted 1 times, ultimately succeeded.
#         shard 6 was attempted 1 times, ultimately succeeded.
#         shard 7 was attempted 1 times, ultimately succeeded.
#         shard 8 was attempted 1 times, ultimately succeeded.
#         shard 9 was attempted 1 times, ultimately succeeded.
#         shard 10 was attempted 1 times, ultimately succeeded.
#         shard 11 was attempted 1 times, ultimately succeeded.
#         shard 12 was attempted 1 times, ultimately succeeded.
#         shard 13 was attempted 1 times, ultimately succeeded.
#         shard 14 was attempted 1 times, ultimately succeeded.
#         shard 15 was attempted 1 times, ultimately succeeded.
#         shard 16 was attempted 1 times, ultimately succeeded.
#         shard 17 was attempted 1 times, ultimately succeeded.
#         shard 18 was attempted 1 times, ultimately succeeded.
#         shard 19 was attempted 1 times, ultimately succeeded.
#         shard 20 was attempted 1 times, ultimately succeeded.
#         shard 21 was attempted 1 times, ultimately succeeded.
#         shard 22 was attempted 1 times, ultimately succeeded.
#         shard 23 was attempted 1 times, ultimately succeeded.
#         shard 24 was attempted 1 times, ultimately succeeded.
#       PBCCSWholeGenome.CallVariants.Discover.Discover has 25 shards,
#         shard 0 was attempted 1 times, ultimately succeeded.
#         shard 1 was attempted 1 times, ultimately succeeded.
#         shard 2 was attempted 1 times, ultimately succeeded.
#         shard 3 was attempted 1 times, ultimately succeeded.
#         shard 4 was attempted 1 times, ultimately succeeded.
#         shard 5 was attempted 1 times, ultimately succeeded.
#         shard 6 was attempted 1 times, ultimately succeeded.
#         shard 7 was attempted 1 times, ultimately succeeded.
#         shard 8 was attempted 1 times, ultimately succeeded.
#         shard 9 was attempted 1 times, ultimately succeeded.
#         shard 10 was attempted 1 times, ultimately succeeded.
#         shard 11 was attempted 1 times, ultimately succeeded.
#         shard 12 was attempted 1 times, ultimately succeeded.
#         shard 13 was attempted 1 times, ultimately succeeded.
#         shard 14 was attempted 1 times, ultimately succeeded.
#         shard 15 was attempted 1 times, ultimately succeeded.
#         shard 16 was attempted 1 times, ultimately succeeded.
#         shard 17 was attempted 1 times, ultimately succeeded.
#         shard 18 was attempted 1 times, ultimately succeeded.
#         shard 19 was attempted 1 times, ultimately succeeded.
#         shard 20 was attempted 1 times, ultimately succeeded.
#         shard 21 was attempted 1 times, ultimately succeeded.
#         shard 22 was attempted 1 times, ultimately succeeded.
#         shard 23 was attempted 1 times, ultimately succeeded.
#         shard 24 was attempted 1 times, ultimately succeeded.
#       PBCCSWholeGenome.CallVariants.Sniffles.Sniffles has 25 shards,
#         shard 0 was attempted 1 times, ultimately succeeded.
#         shard 1 was attempted 1 times, ultimately succeeded.
#         shard 2 was attempted 1 times, ultimately succeeded.
#         shard 3 was attempted 1 times, ultimately succeeded.
#         shard 4 was attempted 1 times, ultimately succeeded.
#         shard 5 was attempted 1 times, ultimately succeeded.
#         shard 6 was attempted 1 times, ultimately succeeded.
#         shard 7 was attempted 1 times, ultimately succeeded.
#         shard 8 was attempted 1 times, ultimately succeeded.
#         shard 9 was attempted 1 times, ultimately succeeded.
#         shard 10 was attempted 1 times, ultimately succeeded.
#         shard 11 was attempted 1 times, ultimately succeeded.
#         shard 12 was attempted 1 times, ultimately succeeded.
#         shard 13 was attempted 1 times, ultimately succeeded.
#         shard 14 was attempted 1 times, ultimately succeeded.
#         shard 15 was attempted 1 times, ultimately succeeded.
#         shard 16 was attempted 1 times, ultimately succeeded.
#         shard 17 was attempted 1 times, ultimately succeeded.
#         shard 18 was attempted 1 times, ultimately succeeded.
#         shard 19 was attempted 1 times, ultimately succeeded.
#         shard 20 was attempted 1 times, ultimately succeeded.
#         shard 21 was attempted 1 times, ultimately succeeded.
#         shard 22 was attempted 1 times, ultimately succeeded.
#         shard 23 was attempted 1 times, ultimately succeeded.
#         shard 24 was attempted 1 times, ultimately succeeded.
#       PBCCSWholeGenome.CallVariants.SubsetBam.SubsetBam has 25 shards,
#         shard 0 was attempted 1 times, ultimately succeeded.
#         shard 1 was attempted 1 times, ultimately succeeded.
#         shard 2 was attempted 1 times, ultimately succeeded.
#         shard 3 was attempted 1 times, ultimately succeeded.
#         shard 4 was attempted 1 times, ultimately succeeded.
#         shard 5 was attempted 1 times, ultimately succeeded.
#         shard 6 was attempted 1 times, ultimately succeeded.
#         shard 7 was attempted 1 times, ultimately succeeded.
#         shard 8 was attempted 1 times, ultimately succeeded.
#         shard 9 was attempted 1 times, ultimately succeeded.
#         shard 10 was attempted 1 times, ultimately succeeded.
#         shard 11 was attempted 1 times, ultimately succeeded.
#         shard 12 was attempted 1 times, ultimately succeeded.
#         shard 13 was attempted 1 times, ultimately succeeded.
#         shard 14 was attempted 1 times, ultimately succeeded.
#         shard 15 was attempted 1 times, ultimately succeeded.
#         shard 16 was attempted 1 times, ultimately succeeded.
#         shard 17 was attempted 1 times, ultimately succeeded.
#         shard 18 was attempted 1 times, ultimately succeeded.
#         shard 19 was attempted 1 times, ultimately succeeded.
#         shard 20 was attempted 1 times, ultimately succeeded.
#         shard 21 was attempted 1 times, ultimately succeeded.
#         shard 22 was attempted 1 times, ultimately succeeded.
#         shard 23 was attempted 1 times, ultimately succeeded.
#         shard 24 was attempted 1 times, ultimately succeeded.
#       PBCCSWholeGenome.CallVariants.DVP.MergeDeepVariantGVCFs is not sharded, was attempted 1 times, ultimately succeeded.
#       PBCCSWholeGenome.CallVariants.DVP.MergeDeepVariantVCFs is not sharded, was attempted 1 times, ultimately succeeded.
#         PBCCSWholeGenome.CallVariants.DVP.DV.DV has 21 shards,
#           shard 0 was attempted 1 times, ultimately succeeded.
#           shard 1 was attempted 1 times, ultimately succeeded.
#           shard 2 was attempted 1 times, ultimately succeeded.
#           shard 3 was attempted 1 times, ultimately succeeded.
#           shard 4 was attempted 1 times, ultimately succeeded.
#           shard 5 was attempted 1 times, ultimately succeeded.
#           shard 6 was attempted 1 times, ultimately succeeded.
#           shard 7 was attempted 1 times, ultimately succeeded.
#           shard 8 was attempted 1 times, ultimately succeeded.
#           shard 9 was attempted 1 times, ultimately succeeded.
#           shard 10 was attempted 1 times, ultimately succeeded.
#           shard 11 was attempted 1 times, ultimately succeeded.
#           shard 12 was attempted 1 times, ultimately succeeded.
#           shard 13 was attempted 1 times, ultimately succeeded.
#           shard 14 was attempted 1 times, ultimately succeeded.
#           shard 15 was attempted 1 times, ultimately succeeded.
#           shard 16 was attempted 1 times, ultimately succeeded.
#           shard 17 was attempted 1 times, ultimately succeeded.
#           shard 18 was attempted 1 times, ultimately succeeded.
#           shard 19 was attempted 1 times, ultimately succeeded.
#           shard 20 was attempted 1 times, ultimately succeeded.
#         PBCCSWholeGenome.CallVariants.DVP.PEPPER.PEPPER has 53 shards,
#           shard 0 was attempted 1 times, ultimately succeeded.
#           shard 1 was attempted 2 times, ultimately succeeded.
#           shard 2 was attempted 3 times, ultimately succeeded.
#           shard 3 was attempted 2 times, ultimately succeeded.
#           shard 4 was attempted 1 times, ultimately succeeded.
#           shard 5 was attempted 4 times, ultimately succeeded.
#           shard 6 was attempted 4 times, ultimately succeeded.
#           shard 7 was attempted 1 times, ultimately succeeded.
#           shard 8 was attempted 4 times, ultimately succeeded.
#           shard 9 was attempted 4 times, ultimately succeeded.
#           shard 10 was attempted 1 times, ultimately succeeded.
#           shard 11 was attempted 1 times, ultimately succeeded.
#           shard 12 was attempted 1 times, ultimately succeeded.
#           shard 13 was attempted 4 times, ultimately succeeded.
#           shard 14 was attempted 2 times, ultimately succeeded.
#           shard 15 was attempted 4 times, ultimately succeeded.
#           shard 16 was attempted 4 times, ultimately succeeded.
#           shard 17 was attempted 1 times, ultimately succeeded.
#           shard 18 was attempted 4 times, ultimately succeeded.
#           shard 19 was attempted 1 times, ultimately succeeded.
#           shard 20 was attempted 4 times, ultimately succeeded.
#         PBCCSWholeGenome.CallVariants.DVP.SubsetBam.SubsetBam has 21 shards,
#           shard 0 was attempted 1 times, ultimately succeeded.
#           shard 1 was attempted 1 times, ultimately succeeded.
#           shard 2 was attempted 1 times, ultimately succeeded.
#           shard 3 was attempted 1 times, ultimately succeeded.
#           shard 4 was attempted 1 times, ultimately succeeded.
#           shard 5 was attempted 1 times, ultimately succeeded.
#           shard 6 was attempted 1 times, ultimately succeeded.
#           shard 7 was attempted 1 times, ultimately succeeded.
#           shard 8 was attempted 1 times, ultimately succeeded.
#           shard 9 was attempted 1 times, ultimately succeeded.
#           shard 10 was attempted 1 times, ultimately succeeded.
#           shard 11 was attempted 1 times, ultimately succeeded.
#           shard 12 was attempted 1 times, ultimately succeeded.
#           shard 13 was attempted 1 times, ultimately succeeded.
#           shard 14 was attempted 1 times, ultimately succeeded.
#           shard 15 was attempted 1 times, ultimately succeeded.
#           shard 16 was attempted 1 times, ultimately succeeded.
#           shard 17 was attempted 1 times, ultimately succeeded.
#           shard 18 was attempted 1 times, ultimately succeeded.
#           shard 19 was attempted 1 times, ultimately succeeded.
#           shard 20 was attempted 1 times, ultimately succeeded.

# %%
with open('/Users/shuang/Desktop/failed.big.workflow.json', 'r') as ff:
    my_2nd_workflow = json.load(ff)

# %%
my_2nd_model = WorkflowMinimumDiagnosisMetadata(my_2nd_workflow)

# %%
my_2nd_model.tree
# Out:
# [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35970>,
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35850>,
#  {'CallAssemblyVariants': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd358b0>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35a30>]},
#  {'FinalizeHifiasmAlternateFa': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35a00>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35580>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd354c0>]},
#  {'FinalizeHifiasmAlternateGfa': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35460>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35040>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35100>]},
#  {'Hifiasm': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35220>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35910>]},
#  {'FinalizeHifiasmPrimaryGfa': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35610>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35280>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35160>]},
#  <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35670>,
#  {'FinalizeHifiasmPrimaryFa': [<src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35250>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35ac0>,
#    <src.cromwell_utils.TaskMinimalDiagnosisMetadata at 0x11fd35b20>]}]

# %%
my_2nd_model.topology()
# Out:
# Workflow:   PBAssembleWithHifiasm
#
# Workflow: PBAssembleWithHifiasm, 15 leaves, 0 simple scatters, 2 subworkflows, 0 complex scatters
#
#   Level-0 subworkflow: PBAssembleWithHifiasm.CallAssemblyVariants, 2 leaves, 0 simple scatters, 0 subworkflows, 0 complex scatters
#
#   Level-0 subworkflow: PBAssembleWithHifiasm.Hifiasm, 2 leaves, 0 simple scatters, 0 subworkflows, 0 complex scatters

# %%
my_2nd_model.diagnose(show_success_too=False)
# Out:
# Workflow:   PBAssembleWithHifiasm
#             (uuid: 86585cc9-1a3d-46cc-a616-8aed202a7acd)
# Status:     Failed
# Wall-Clock: 2:28
#
#
# Diagnosis
#
#   PBAssembleWithHifiasm.FinalizeHifiasmAlternateFa is not sharded, was attempted 3 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/PBAssembleWithHifiasm/86585cc9-1a3d-46cc-a616-8aed202a7acd/call-FinalizeHifiasmAlternateFa/attempt-3/FinalizeHifiasmAlternateFa.log
#   PBAssembleWithHifiasm.FinalizeHifiasmAlternateGfa is not sharded, was attempted 3 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/PBAssembleWithHifiasm/86585cc9-1a3d-46cc-a616-8aed202a7acd/call-FinalizeHifiasmAlternateGfa/attempt-3/FinalizeHifiasmAlternateGfa.log
#   PBAssembleWithHifiasm.FinalizeHifiasmPrimaryFa is not sharded, was attempted 3 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/PBAssembleWithHifiasm/86585cc9-1a3d-46cc-a616-8aed202a7acd/call-FinalizeHifiasmPrimaryFa/attempt-3/FinalizeHifiasmPrimaryFa.log
#   PBAssembleWithHifiasm.FinalizeHifiasmPrimaryGfa is not sharded, was attempted 3 times, ultimately failed. PAPI codes for all attempts in order: []. Last attempt log file: gs://broad-dsp-lrma-cromwell/PBAssembleWithHifiasm/86585cc9-1a3d-46cc-a616-8aed202a7acd/call-FinalizeHifiasmPrimaryGfa/attempt-3/FinalizeHifiasmPrimaryGfa.log
